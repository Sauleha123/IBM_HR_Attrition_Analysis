# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set(style = 'whitegrid')

# %%
#Load the dataset
df = pd.read_csv("IBM_HR.csv")

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Check for missing values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Basic Stats of the dataset
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### Attrition Distribution

# %%
attrition_rate = df['Attrition'].value_counts(normalize=True) * 100
print("\n Attrition Rate (%): \n", attrition_rate)

plt.figure(figsize=(6,4))
ax = sns.countplot(data=df, x='Attrition', palette='Set2')

total = len(df)
for p in ax.patches:
    count = p.get_height()
    percentage = count / total * 100
    ax.annotate(f'{percentage: .1f}%',
                (p.get_x() + p.get_width() / 2., count),
                ha='center', va='bottom', fontsize = 12, color = 'black')
    
plt.title('Overall Attrition Percentage')
plt.xlabel('Attrition')
plt.ylabel('Number of Employees')
plt.show()
# Out:
#  Attrition Rate (%):
#  Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %% [markdown]
# ####
# - Around 16.1% of employees have left the company, while 83.9% stayed.
# - Indicates a relatively moderate attrition rate but still worth investigating causes.

# %% [markdown]
# ### Attrition by Department

# %%
plt.figure(figsize=(8,5))
sns.countplot(data = df, x = 'Department', hue = 'Attrition', palette = 'Set1')
plt.title('Attrition by Department')
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ####
# - Sales and R&D departments have higher attrition counts compared to Human Resources.
# - R&D retains the highest number of employees but still sees notable exits.

# %% [markdown]
# ### Attrition by Job Role

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='JobRole', hue='Attrition', palette='Set2')
plt.title('Attrition by Job Role')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ####
# - Sales Executive, Research Scientist and Laboratory Technician roles have the highest attrition counts.
# - Manager and Research Director roles have comparatively lower attrition.

# %% [markdown]
# ### Attrition by Gender

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=df, x='Gender', hue='Attrition', palette='pastel')
plt.title('Attrition by Gender')
plt.show()

# %% [markdown]
# ####
# - Attrition is higher in males compared to females.
# - The workforce is male-dominated in this dataset.

# %% [markdown]
# ### Attrition by Age Group

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df, x='Age', hue='Attrition', multiple='stack', palette='Set2', bins=15)
plt.title('Attrition by Age Group')
plt.grid(False)
plt.show()

# %% [markdown]
# ####
# - Higher attrition rates are observed among younger employees (20-30 years), indicating possible career mobility or dissatisfaction early in tenure.
# - Attrition gradually declines as age increases, with the lowest attrition seen in employees above 50 years.
# - Mid-career employees (30,40 years) show moderate attrition, potentially due to better job stability or higher responsibilities.

# %% [markdown]
# ### Monthly Income vs Attrition

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='Attrition', y='MonthlyIncome', palette='coolwarm')
plt.title('Monthly Income vs Attrition')
plt.show()

# %% [markdown]
# ####
# - Employees with lower monthly incomes are more likely to leave.
# - Higher income groups tend to have lower attrition.

# %% [markdown]
# ## Handling Outliers
# ##### Since we cannot remove the outliers completely because it might impact the insights, so we will just plot the graphs representing them with and without outliers.

# %%
df['MonthlyIncome'] = pd.to_numeric(df['MonthlyIncome'], errors='coerce')

Q1 = df['MonthlyIncome'].quantile(0.25)
Q3 = df['MonthlyIncome'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df['Outlier_Flag'] = ((df['MonthlyIncome'] < lower_bound) | (df['MonthlyIncome'] > upper_bound)).astype(int)
print(f"Number of Outlier: {df['Outlier_Flag'].sum()}")

df_no_outliers = df[df['Outlier_Flag'] == 0]

plt.figure(figsize=(14,6))

# Box Plot With Outliers

plt.subplot(1,2,1)
sns.boxplot(data=df, x='Attrition', y='MonthlyIncome', palette='pastel')
plt.title('Monthly Income vs Attrition (With Outliers)')

# Box Plot Without Outliers

plt.subplot(1,2,2)
sns.boxplot(data=df_no_outliers, x='Attrition', y='MonthlyIncome', palette='pastel', showfliers=False)
plt.title('Monthly Income vs Attrition (Without Outliers)')

plt.tight_layout()
plt.show()
# Out:
# Number of Outlier: 114

# %% [markdown]
# ####
# - Outliers in Monthly Income are primarily on the higher end, representing a small group of higher paid employees.
# - Removing outliers reduces the spread but does not significantly affect the median income for either attrition group.
# - High-income outliers are more prevalent among employees who stayed, suggesting better compensation may contribute to retention.

# %% [markdown]
# ### Correlation Heatmap (Numerical Features)

# %%
plt.figure(figsize=(14,10))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap of Numerical Features')
plt.grid(False)
plt.show()

# %% [markdown]
# ####
# - Strong correlations found between **Job Level** and **Monthly Income**, and between **Total Working Years** and **Job Level.**
# - Attrition does not have a strong linear correlation with most numerical variables, suggesting other factors may play a role.

# %% [markdown]
# ### Overtime vs Attrition

# %%
plt.figure(figsize=(6,5))
sns.countplot(data=df, x='OverTime', hue='Attrition', palette='pastel')
plt.title('Overtime vs Attrition')
plt.xlabel('Overtime')
plt.ylabel('Count')
plt.show()

overtime_attrition = df.groupby('OverTime')['Attrition'].value_counts(normalize=True).unstack() * 100
print(overtime_attrition)
# Out:
# Attrition         No        Yes
# OverTime
# No         89.563567  10.436433
# Yes        69.471154  30.528846

# %% [markdown]
# ####
# - Employees doing overtime have a significantly higher attrition percentage compared to those without overtime.

# %% [markdown]
# ### Years at Company vs Attrition

# %%
plt.figure(figsize=(14,5))
sns.countplot(data=df, x='YearsAtCompany', hue='Attrition', palette='pastel')
plt.title('Years at Company vs Attrition')
plt.xlabel('Years at Company')
plt.ylabel('Count')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ####
# - Attrition is higher among employees with fewer years at the company.
# - Very low attrition among employees with **10+ Years** of service.

# %% [markdown]
# ### Department & MonthlyIncome vs Attrition

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Department', y='MonthlyIncome', hue='Attrition', palette='pastel')
plt.title('Department & Monthly Income vs Attrition')
plt.xticks(rotation=45)
plt.legend(title='Attrition', loc='upper right', bbox_to_anchor=(1.15,1))
plt.show()

# %% [markdown]
# ####
# - In all the departments, employees with lower incomes show higher attrition.
# - The effect is most visible in Sales and R&D.

# %% [markdown]
# ### Job Satisfaction & Environment Satisfaction vs Attrition

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

sns.countplot(data=df, x='JobSatisfaction', hue='Attrition', palette='pastel', ax=axes[0])
axes[0].set_title("Job Satisfaction vs Attrition")
axes[0].set_xlabel("Job Satisfaction (1=Low, 4=High)")

sns.countplot(data=df, x='EnvironmentSatisfaction', hue='Attrition', palette='pastel', ax=axes[1])
axes[1].set_title("Environment Satisfaction vs Attrition")
axes[1].set_xlabel("Environment Satisfaction (1=Low, 4=High)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ####
# - Lower job satisfaction and environment satisfaction levels are associated with higher attrition.

# %% [markdown]
# ## Key Insights:
# The analysis of IBM HR Employee Attrition data reveals several key factors influencing employee turnover:
#
# - Income & Compensation:
# Lower monthly income is strongly associated with higher attrition. High-income employees are more likely to stay, and income outliers (very high salaries) are mostly in the non-attrition group.
#
# - Tenure & Experience:
# Employees with fewer years at the company, especially under 3 years, have significantly higher attrition rates. Long-term employes (10+ years) rarely leave.
#
# - Age Factor:
# Younger employees (20-30 years) show the highest attrition, suggesting career exploration, lack of engagement, or better opportunities elsewhere. Attrition decreases steadily with age.
#
# - Job Roles & Departments:
# Certain roles particularly Sales Executive, Research Scientist, and Laboratory Technician face higher attrition. Human Resources shows the lowest turnover.
#
# - Overtime & Workload:
# Overtime workers have substantially higher attrition rates, indicating that workload and work-life balance play an important role in retention.
#
# - Satisfaction Levels:
# Lower job satisfaction and environment scores (1-2) correlate with higher attrition, highlighting the importance of employee engagement and workplace environment.
#
# - Gender Distribution:
# While males slightly outnumber females in the workforce, attrition appears more influenced by role,pay, and satisfaction than by gender.
#
#
# ### Overall, the findings suggest that IBM can reduce attrition by:
# - Improving pay structures for lower-income employees.
# - Addressing workload and overtime concerns.
# - Focusing on engagement and satisfaction in high-turnover job roles.
# - Implementing targeted retention programs for younger and early-tenure employees.

# %%
df.to_csv("Cleaned_IBM_HR.csv", index=False)
